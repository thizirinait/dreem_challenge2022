# %% [markdown]
# * Student : Thiziri NAIT SAADA

# %% [markdown]
# **Machine Learning for Time Series (Master MVA)**
#
# - Tutorial 2, Friday 29<sup>th</sup> January 2021
# - [Link to the class material.](http://www.laurentoudre.fr/ast.html)

# %% [markdown]
# # Introduction
#
# In this tutorial, we illustrate the following concepts:
#
# - feature extraction on time series
# - feature selection

# %% [markdown]
# ## Setup
#
# **Imports**

# %%
from itertools import tee

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from loadmydata.load_uea_ucr import load_uea_ucr_data
from numpy.fft import rfft, rfftfreq
import scipy
from scipy.cluster import hierarchy
from scipy.signal import argrelmax, stft
from scipy.spatial.distance import pdist, squareform
from scipy.stats import f_oneway, spearmanr
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.neighbors import KNeighborsClassifier
from statsmodels.tsa.stattools import acf

# %% [markdown]
# **Utility functions**

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
def get_largest_local_max(signal1D: np.ndarray, order: int = 1):
    """Return the largest local max and the associated index in a tuple.

    This function uses `order` points on each side to use for the comparison.
    """
    all_local_max_indexes = argrelmax(signal1D, order=order)[0]
    all_local_max = np.take(signal1D, all_local_max_indexes)
    largest_local_max_index = all_local_max_indexes[
        all_local_max.argsort()[-1]
    ]

    return signal1D[largest_local_max_index], largest_local_max_index

# %%
def fig_ax(figsize=(15, 5)):
    return plt.subplots(figsize=figsize)

# %% [markdown]
# ## Data

# %%
dataset_name = "BinaryHeartbeat"
data = load_uea_ucr_data(dataset_name)
print(data.description)
# Out:
# Task is to classify the nature of the heartbeat signal.
#
# Heart sound recordings were sourced from several contributors around the world, collected at either a clinical or nonclinical environment, from both healthy subjects and pathological patients.
# Each series represent the aplitude of the singal over time.
#
# Heart sound recordings were sourced from several contributors around the world, collected at either a clinical or nonclinical environment, from both healthy subjects and pathological patients.
# The heart sound recordings were collected from different locations on the body. The typical four locations are aortic area, pulmonic area, tricuspid area and mitral area, but could be one of nine different locations.
# The sounds were divided into two classes: normal and abnormal. The normal recordings were from healthy subjects and the abnormal ones were from patients with a confirmed cardiac diagnosis.
# The patients suffer from a variety of illnesses, but typically they are heart valve defects and coronary artery disease patients.
# Heart valve defects include mitral valve prolapse, mitral regurgitation, aortic stenosis and valvular surgery. All the recordings from the patients were generally labeled as abnormal.
# Both healthy subjects and pathological patients include both children and adults.
#
# Data was recorded at 2,000Hz.
# Data was truncated to the shortest instance.
#
# Original data can be found here:
# https://www.physionet.org/physiobank/database/challenge/2016/
#
# Original paper:
# Goldberger AL, Amaral LA, Glass L, Hausdorff JM, Ivanov PC, Mark RG, Mietus JE, Moody GB, Peng CK, Stanley HE. PhysioBank, PhysioToolkit, and PhysioNet: components of a new research resource for complex physiologic signals. circulation. 2000 Jun 13;101(23):e215-20.
#
# Correspondence should be addressed to Ary L. Goldberger:
# ary@astro.bidmc.harvard.edu
#
# Instances: 409
# Time series length: 18,530
# Classes:
# - Normal (110)
# - Abnormal (299)
# default train test split created through a random partition.

# %%
# Sampling frequency
FREQUENCY = 2000  # Hz

# %% [markdown]
# Choose a signal from the data set.

# %%
signal = data.X_train[0].flatten()
n_samples = signal.shape[0]

# %%
fig, ax = fig_ax()
tt = np.arange(n_samples) / FREQUENCY
ax.plot(tt, signal)

# %% [markdown]
# Compute the spectrogram

# %%
f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=1000, noverlap=800)

# %%
fig, ax = fig_ax()
ax.pcolormesh(t, f, np.abs(Zxx), vmin=0, shading="gouraud")
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Replot the same spectrogram as above, but zoom on the interesting frequencies (set <tt>cut_off_freq</tt> in the following cell).</p>
#     <ul>
#         <li>What are the repeated patterns? What is the frequency of interest (approximately)?</li>
#         <li>What happens when you increase the number of samples per windows?</li>
#         <li>What happens when you increase the overlap between windows?</li>
#     </ul>
# </div>

# %%
# Cut-off frequency
cut_off_freq = 200  # Hz

# %%
## changing nperseg

fig, ax = fig_ax()

f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=1024, noverlap=512)

keep_mask = f < cut_off_freq

ax.pcolormesh(
    t, f[keep_mask], np.abs(Zxx[keep_mask]), vmin=0, shading="gouraud"
)
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %%
## changing nperseg

fig, ax = fig_ax()

f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=2048, noverlap=512)

keep_mask = f < cut_off_freq

ax.pcolormesh(
    t, f[keep_mask], np.abs(Zxx[keep_mask]), vmin=0, shading="gouraud"
)
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %%
## changing noverlap

fig, ax = fig_ax()

f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=512, noverlap=200)

keep_mask = f < cut_off_freq

ax.pcolormesh(
    t, f[keep_mask], np.abs(Zxx[keep_mask]), vmin=0, shading="gouraud"
)
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %% [markdown]
# * Answer :
#
#
# Les motifs répétés correspondent aux motifs contenus dans les battements du coeur. Les fréquences d'interet se situent en dessous de 200 Hz. Les points de couleur sont des fréquences de haut coefficient, donc toutes les demi secondes on a des bruits, plus ou moins 'grands', c'est une sorte de motif.
#
# Si on change la taille de la fenêtre (2048), on est plus précis dans le domaine des fréquences, mais moins précis dans le domaine temporel (car on aura deux ou trois battements). Il y a un compromis précision temps-fréquence, régi par la taille de la fenêtre.
#
# Pour le paramètre d'overlap : On a une meilleure résolution temporelle si l'overlap est grand, mais il fait augmenter la complexité (les calculs sont plus lents).

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Statistical features

# %% [markdown]
# ### Moments and percentiles

# %%
def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max()
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': -4.36204926670265e-05,
#  'std': 0.053476347507460366,
#  'min': -0.3250732,
#  'max': 0.2915039}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Rewrite in the following cell, the function <tt>get_distribution_features(signal)->dict</tt> so that is also computes the kurtosis, the skew (available in the <tt>scipy.stats</tt> module) and the 25%, 50% and 75% percentiles.</p>
# </div>

# %%
def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max()
    res_dict["skew"] = scipy.stats.skew(signal)
    res_dict["quarter"] = np.percentile(signal, 25)
    res_dict["two_quarter"] = np.percentile(signal, 50)
    res_dict["three_quarter"] = np.percentile(signal, 75)
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': -4.36204926670265e-05,
#  'std': 0.053476347507460366,
#  'min': -0.3250732,
#  'max': 0.2915039,
#  'skew': 0.28696295903662516,
#  'quarter': -0.02713013,
#  'two_quarter': -0.0006103516,
#  'three_quarter': 0.02511597}

# %% [markdown]
# ### Autocorrelation

# %% [markdown]
# For a signal $x\in\mathbb{R}^N$ with $N$ samples, the autocorrelation with lag $m$ is defined as follows:
#
# $$
# \hat{\gamma}[m] := \frac{1}{N-|m|} \sum_{n=0}^{N-1} x[n]x[n+m].
# $$
#
# Note that if the signal $x$ is periodic, then the autocorrelation is also periodic with same period.

# %% [markdown]
# Let us plot the autocorrelation of a sound signal.

# %%
fig, ax = fig_ax()
ax.plot(acf(signal, nlags=200, fft=True), ".-")
ax.axhline(0, ls="--", color="k")
plt.show()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>We would like to also compute the maximum autocorrelation value and the associated lag in Hz (a local maximum that is not 0). Explain how you can convert a lag expressed in number of samples to a lag expressed in Hz.</p>
# </div>

# %% [markdown]
# Pour transformer un lag en fréquence : on divise la fréquence d'échantillonnage par le lag
# Ici, on a un maximum d'autocorrélation au 100ème lag (en excluant 0). Donc tous les 100 points, nous avons une forte corrélation, ce qui correspond à 2000/100 = 20 Hz

# %% [markdown]
# Compute the autocorrelation features.

# %%
def get_autocorr_features(signal: np.ndarray, n_lags: int = 200) -> dict:
    auto_corr = acf(signal, nlags=n_lags, fft=True)
    res_dict = dict()
    for (lag, auto_corr_value) in enumerate(auto_corr):
        res_dict[f"autocorrelation_{lag}_lag"] = auto_corr_value

    local_max, local_argmax = get_largest_local_max(auto_corr, order=20)
    res_dict["lag_max_autocorrelation_Hz"] = FREQUENCY / local_argmax
    res_dict["max_autocorrelation"] = local_max

    return res_dict

# %%
get_autocorr_features(signal, n_lags=100)
# Out:
# {'autocorrelation_0_lag': 1.0,
#  'autocorrelation_1_lag': 0.9878346636837038,
#  'autocorrelation_2_lag': 0.9539436420458182,
#  'autocorrelation_3_lag': 0.9019015664004297,
#  'autocorrelation_4_lag': 0.8371394434711026,
#  'autocorrelation_5_lag': 0.7642879203951046,
#  'autocorrelation_6_lag': 0.6869953069390051,
#  'autocorrelation_7_lag': 0.6077263361362768,
#  'autocorrelation_8_lag': 0.5278428777248149,
#  'autocorrelation_9_lag': 0.44807529893529446,
#  'autocorrelation_10_lag': 0.36878531428200517,
#  'autocorrelation_11_lag': 0.2904319128393836,
#  'autocorrelation_12_lag': 0.2135843409306105,
#  'autocorrelation_13_lag': 0.1391579881199314,
#  'autocorrelation_14_lag': 0.0681155536375731,
#  'autocorrelation_15_lag': 0.00153175607494485,
#  'autocorrelation_16_lag': -0.05982668166177405,
#  'autocorrelation_17_lag': -0.11537747797593947,
#  'autocorrelation_18_lag': -0.1650154245069034,
#  'autocorrelation_19_lag': -0.20879735631315996,
#  'autocorrelation_20_lag': -0.24706403734001328,
#  'autocorrelation_21_lag': -0.2800871788450011,
#  'autocorrelation_22_lag': -0.3081908758365509,
#  'autocorrelation_23_lag': -0.3315089007310145,
#  'autocorrelation_24_lag': -0.3501835950704428,
#  'autocorrelation_25_lag': -0.3642108428221865,
#  'autocorrelation_26_lag': -0.373667316345464,
#  'autocorrelation_27_lag': -0.37863548552537973,
#  'autocorrelation_28_lag': -0.37926049538893547,
#  'autocorrelation_29_lag': -0.37576001516976526,
#  'autocorrelation_30_lag': -0.3683228277789211,
#  'autocorrelation_31_lag': -0.35712048030610904,
#  'autocorrelation_32_lag': -0.3423271779094116,
#  'autocorrelation_33_lag': -0.3241544612915392,
#  'autocorrelation_34_lag': -0.30288790360860857,
#  'autocorrelation_35_lag': -0.2789734799408917,
#  'autocorrelation_36_lag': -0.2529137225810937,
#  'autocorrelation_37_lag': -0.2253381233075421,
#  'autocorrelation_38_lag': -0.19684843697856053,
#  'autocorrelation_39_lag': -0.168023099095667,
#  'autocorrelation_40_lag': -0.13943782052140025,
#  'autocorrelation_41_lag': -0.11156357029400861,
#  'autocorrelation_42_lag': -0.0848482215567208,
#  'autocorrelation_43_lag': -0.059649290884909396,
#  'autocorrelation_44_lag': -0.03633053283319134,
#  'autocorrelation_45_lag': -0.015222023575950604,
#  'autocorrelation_46_lag': 0.003349474562218545,
#  'autocorrelation_47_lag': 0.01913967314261183,
#  'autocorrelation_48_lag': 0.03194172381216762,
#  'autocorrelation_49_lag': 0.0416715560810148,
#  'autocorrelation_50_lag': 0.048312995200361177,
#  'autocorrelation_51_lag': 0.051931058715674806,
#  'autocorrelation_52_lag': 0.05259702058107732,
#  'autocorrelation_53_lag': 0.05040309945346897,
#  'autocorrelation_54_lag': 0.04543152072644377,
#  'autocorrelation_55_lag': 0.037710047214055006,
#  'autocorrelation_56_lag': 0.027325026756214517,
#  'autocorrelation_57_lag': 0.01435191320724522,
#  'autocorrelation_58_lag': -0.0010188425296251199,
#  'autocorrelation_59_lag': -0.01853244782758933,
#  'autocorrelation_60_lag': -0.03780856118060254,
#  'autocorrelation_61_lag': -0.0583781246767879,
#  'autocorrelation_62_lag': -0.07971126121316431,
#  'autocorrelation_63_lag': -0.10122704097837272,
#  'autocorrelation_64_lag': -0.12237505824634415,
#  'autocorrelation_65_lag': -0.1426486688614802,
#  'autocorrelation_66_lag': -0.1616164464932969,
#  'autocorrelation_67_lag': -0.178962678568969,
#  'autocorrelation_68_lag': -0.19441021326442504,
#  'autocorrelation_69_lag': -0.20779568783360686,
#  'autocorrelation_70_lag': -0.21896560608272636,
#  'autocorrelation_71_lag': -0.22780766284055096,
#  'autocorrelation_72_lag': -0.23423609800987297,
#  'autocorrelation_73_lag': -0.23817406508057903,
#  'autocorrelation_74_lag': -0.23959055515438926,
#  'autocorrelation_75_lag': -0.23845645517925856,
#  'autocorrelation_76_lag': -0.23480331114590977,
#  'autocorrelation_77_lag': -0.22865376957421005,
#  'autocorrelation_78_lag': -0.22011366981774255,
#  'autocorrelation_79_lag': -0.20924783552593149,
#  'autocorrelation_80_lag': -0.19622041017669214,
#  'autocorrelation_81_lag': -0.181165717983397,
#  'autocorrelation_82_lag': -0.16429517066410426,
#  'autocorrelation_83_lag': -0.14581458279684492,
#  'autocorrelation_84_lag': -0.12596322910833258,
#  'autocorrelation_85_lag': -0.1050060131262428,
#  'autocorrelation_86_lag': -0.08319860396399147,
#  'autocorrelation_87_lag': -0.060838012722933425,
#  'autocorrelation_88_lag': -0.03824515024703427,
#  'autocorrelation_89_lag': -0.015753055172882474,
#  'autocorrelation_90_lag': 0.006299229785178307,
#  'autocorrelation_91_lag': 0.027554901388277406,
#  'autocorrelation_92_lag': 0.04769058796728643,
#  'autocorrelation_93_lag': 0.06636662193133662,
#  'autocorrelation_94_lag': 0.08331673021314655,
#  'autocorrelation_95_lag': 0.09826578021067985,
#  'autocorrelation_96_lag': 0.11099911365235116,
#  'autocorrelation_97_lag': 0.12131740133164379,
#  'autocorrelation_98_lag': 0.12907567451385124,
#  'autocorrelation_99_lag': 0.1341928000789746,
#  'autocorrelation_100_lag': 0.13666303526893825,
#  'lag_max_autocorrelation_Hz': 38.46153846153846,
#  'max_autocorrelation': 0.05259702058107732}

# %% [markdown]
# ## Spectral features

# %% [markdown]
# Plot the Fourier coefficients of a signal (y=absolute value, x=frequency) using `rfft()` and `rfftfreq()`.

# %%
fourier = abs(rfft(signal)) ** 2
freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)

fig, ax = fig_ax()
ax.plot(freqs, fourier)
ax.set_xlabel("Frequency (Hz)")
_ = ax.set_ylabel("Fourier coefficient")

# %% [markdown]
# Compute the spectral features.

# %%
def get_fourier_features(signal: np.ndarray, n_bins: int = 100) -> dict:
    """The signal is assumed to be centered and scaled to unit variance."""

    n_samples = signal.shape[0]
    fourier = abs(rfft(signal))
    freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)
    res_dict = dict()

    freq_bins = np.linspace(0, FREQUENCY / 2, n_bins + 1)
    for (f_min, f_max) in pairwise(freq_bins):
        keep = (f_min <= freqs) & (freqs < f_max)
        res_dict[f"fourier_{f_min:.1f}-{f_max:.1f}_Hz"] = np.log(
            np.sum(fourier[keep] ** 2)
        )
    return res_dict

# %%
get_fourier_features(signal, n_bins=10)
# Out:
# {'fourier_0.0-100.0_Hz': 13.062805200766368,
#  'fourier_100.0-200.0_Hz': 9.789782046195757,
#  'fourier_200.0-300.0_Hz': 7.474775836054673,
#  'fourier_300.0-400.0_Hz': 5.042830727182429,
#  'fourier_400.0-500.0_Hz': 3.271908511560872,
#  'fourier_500.0-600.0_Hz': 2.034724789695899,
#  'fourier_600.0-700.0_Hz': 2.072603298867695,
#  'fourier_700.0-800.0_Hz': 2.6515556177815025,
#  'fourier_800.0-900.0_Hz': 2.993208438886878,
#  'fourier_900.0-1000.0_Hz': 3.172705345844466}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>The frequency features are not scaled. If the signal is normalized, do we need to?</p>
# </div>

# %% [markdown]
# * Answer: Theoreme de Parseval nous donne conversation de l'énergie du signal, qu'il soit temporel ou fréquentiel (à un facteur 2 * pi près en fonction de la convention choisie pour la TF).
#
#     Donc si le signal est normalisé dans le domaine temporel, il va de soit par cette égalité qu'il l'est également dans le domaine fréquentiel, donc pas la peine de normaliser.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> We have used regularly spaced frequency bins. What would be a better approach? </p>
#
# </div>

# %% [markdown]
# * Answer : On aurait pu prendre des bins plus adaptées au signal d'étude, par exemple prendre toutes les bins entre 0 et 200 Hz (exemple échelle Mel = échelle logarithmique plus adaptée aux fréquences audibles par l homme)

# %% [markdown]
# ## Concatenate all features

# %% [markdown]
# In the following cell, we write a function `get_features(signal: np.ndarray) -> dict` that computes all features from above.

# %%
def get_features(signal: np.ndarray) -> dict:
    res_dict = dict()

    # stats
    res_dict.update(get_distribution_features(signal))

    # spectral
    signal -= signal.mean()
    signal /= signal.std()
    res_dict.update(get_fourier_features(signal, n_bins=50))

    # autocorrelation
    res_dict.update(get_autocorr_features(signal, n_lags=200))

    return res_dict

# %%
get_features(signal)
# Out:
# {'mean': -4.36204926670265e-05,
#  'std': 0.053476347507460366,
#  'min': -0.3250732,
#  'max': 0.2915039,
#  'skew': 0.28696295903662516,
#  'quarter': -0.02713013,
#  'two_quarter': -0.0006103516,
#  'three_quarter': 0.02511597,
#  'fourier_0.0-20.0_Hz': 17.425511109475327,
#  'fourier_20.0-40.0_Hz': 18.08989281619167,
#  'fourier_40.0-60.0_Hz': 17.489366231711315,
#  'fourier_60.0-80.0_Hz': 16.265620325645486,
#  'fourier_80.0-100.0_Hz': 15.412438705688363,
#  'fourier_100.0-120.0_Hz': 14.740121990157501,
#  'fourier_120.0-140.0_Hz': 14.11903917348016,
#  'fourier_140.0-160.0_Hz': 13.870068979262031,
#  'fourier_160.0-180.0_Hz': 13.582886659613838,
#  'fourier_180.0-200.0_Hz': 13.157674451752792,
#  'fourier_200.0-220.0_Hz': 12.67154916631504,
#  'fourier_220.0-240.0_Hz': 11.825080871850867,
#  'fourier_240.0-260.0_Hz': 11.255058694087516,
#  'fourier_260.0-280.0_Hz': 10.84329864883104,
#  'fourier_280.0-300.0_Hz': 10.39955950521556,
#  'fourier_300.0-320.0_Hz': 9.890567601073453,
#  'fourier_320.0-340.0_Hz': 9.58705281499147,
#  'fourier_340.0-360.0_Hz': 9.188995074055711,
#  'fourier_360.0-380.0_Hz': 8.645898685416844,
#  'fourier_380.0-400.0_Hz': 8.38370966543529,
#  'fourier_400.0-420.0_Hz': 8.051003827274839,
#  'fourier_420.0-440.0_Hz': 7.731607048953479,
#  'fourier_440.0-460.0_Hz': 7.450347500206699,
#  'fourier_460.0-480.0_Hz': 7.014887152886689,
#  'fourier_480.0-500.0_Hz': 6.875749029206018,
#  'fourier_500.0-520.0_Hz': 6.56895179104723,
#  'fourier_520.0-540.0_Hz': 6.193628207989099,
#  'fourier_540.0-560.0_Hz': 6.436477831955529,
#  'fourier_560.0-580.0_Hz': 6.01010965407203,
#  'fourier_580.0-600.0_Hz': 6.089417460480804,
#  'fourier_600.0-620.0_Hz': 6.071361635325678,
#  'fourier_620.0-640.0_Hz': 6.300262020106506,
#  'fourier_640.0-660.0_Hz': 6.234504126007419,
#  'fourier_660.0-680.0_Hz': 6.428478940550233,
#  'fourier_680.0-700.0_Hz': 6.508990462396062,
#  'fourier_700.0-720.0_Hz': 6.846653273675549,
#  'fourier_720.0-740.0_Hz': 6.652063380023944,
#  'fourier_740.0-760.0_Hz': 6.762563623765137,
#  'fourier_760.0-780.0_Hz': 7.0583956473541685,
#  'fourier_780.0-800.0_Hz': 7.102180136547861,
#  'fourier_800.0-820.0_Hz': 7.053912666023326,
#  'fourier_820.0-840.0_Hz': 7.210071570949587,
#  'fourier_840.0-860.0_Hz': 7.281311046856824,
#  'fourier_860.0-880.0_Hz': 7.291408810734029,
#  'fourier_880.0-900.0_Hz': 7.342887774206717,
#  'fourier_900.0-920.0_Hz': 7.395765109126664,
#  'fourier_920.0-940.0_Hz': 7.687514992541046,
#  'fourier_940.0-960.0_Hz': 7.582547372242515,
#  'fourier_960.0-980.0_Hz': 7.349332294240741,
#  'fourier_980.0-1000.0_Hz': 6.926441922399656,
#  'autocorrelation_0_lag': 1.0,
#  'autocorrelation_1_lag': 0.9878346636837039,
#  'autocorrelation_2_lag': 0.9539436420458183,
#  'autocorrelation_3_lag': 0.9019015664004298,
#  'autocorrelation_4_lag': 0.8371394434711027,
#  'autocorrelation_5_lag': 0.7642879203951047,
#  'autocorrelation_6_lag': 0.6869953069390051,
#  'autocorrelation_7_lag': 0.6077263361362769,
#  'autocorrelation_8_lag': 0.527842877724815,
#  'autocorrelation_9_lag': 0.4480752989352946,
#  'autocorrelation_10_lag': 0.36878531428200517,
#  'autocorrelation_11_lag': 0.2904319128393836,
#  'autocorrelation_12_lag': 0.2135843409306105,
#  'autocorrelation_13_lag': 0.1391579881199314,
#  'autocorrelation_14_lag': 0.06811555363757311,
#  'autocorrelation_15_lag': 0.0015317560749448544,
#  'autocorrelation_16_lag': -0.059826681661774066,
#  'autocorrelation_17_lag': -0.11537747797593949,
#  'autocorrelation_18_lag': -0.16501542450690337,
#  'autocorrelation_19_lag': -0.20879735631316,
#  'autocorrelation_20_lag': -0.24706403734001334,
#  'autocorrelation_21_lag': -0.2800871788450012,
#  'autocorrelation_22_lag': -0.30819087583655086,
#  'autocorrelation_23_lag': -0.3315089007310145,
#  'autocorrelation_24_lag': -0.35018359507044283,
#  'autocorrelation_25_lag': -0.3642108428221866,
#  'autocorrelation_26_lag': -0.37366731634546413,
#  'autocorrelation_27_lag': -0.3786354855253798,
#  'autocorrelation_28_lag': -0.3792604953889355,
#  'autocorrelation_29_lag': -0.3757600151697653,
#  'autocorrelation_30_lag': -0.3683228277789211,
#  'autocorrelation_31_lag': -0.35712048030610916,
#  'autocorrelation_32_lag': -0.34232717790941164,
#  'autocorrelation_33_lag': -0.3241544612915392,
#  'autocorrelation_34_lag': -0.3028879036086086,
#  'autocorrelation_35_lag': -0.2789734799408918,
#  'autocorrelation_36_lag': -0.25291372258109374,
#  'autocorrelation_37_lag': -0.22533812330754213,
#  'autocorrelation_38_lag': -0.19684843697856053,
#  'autocorrelation_39_lag': -0.16802309909566707,
#  'autocorrelation_40_lag': -0.13943782052140025,
#  'autocorrelation_41_lag': -0.11156357029400865,
#  'autocorrelation_42_lag': -0.0848482215567208,
#  'autocorrelation_43_lag': -0.05964929088490941,
#  'autocorrelation_44_lag': -0.036330532833191334,
#  'autocorrelation_45_lag': -0.015222023575950611,
#  'autocorrelation_46_lag': 0.0033494745622185346,
#  'autocorrelation_47_lag': 0.019139673142611828,
#  'autocorrelation_48_lag': 0.03194172381216762,
#  'autocorrelation_49_lag': 0.0416715560810148,
#  'autocorrelation_50_lag': 0.04831299520036117,
#  'autocorrelation_51_lag': 0.05193105871567481,
#  'autocorrelation_52_lag': 0.052597020581077326,
#  'autocorrelation_53_lag': 0.05040309945346897,
#  'autocorrelation_54_lag': 0.04543152072644376,
#  'autocorrelation_55_lag': 0.03771004721405501,
#  'autocorrelation_56_lag': 0.02732502675621452,
#  'autocorrelation_57_lag': 0.014351913207245217,
#  'autocorrelation_58_lag': -0.0010188425296251205,
#  'autocorrelation_59_lag': -0.018532447827589338,
#  'autocorrelation_60_lag': -0.03780856118060256,
#  'autocorrelation_61_lag': -0.058378124676787914,
#  'autocorrelation_62_lag': -0.07971126121316435,
#  'autocorrelation_63_lag': -0.10122704097837278,
#  'autocorrelation_64_lag': -0.12237505824634418,
#  'autocorrelation_65_lag': -0.1426486688614802,
#  'autocorrelation_66_lag': -0.1616164464932969,
#  'autocorrelation_67_lag': -0.17896267856896902,
#  'autocorrelation_68_lag': -0.19441021326442512,
#  'autocorrelation_69_lag': -0.2077956878336069,
#  'autocorrelation_70_lag': -0.21896560608272636,
#  'autocorrelation_71_lag': -0.22780766284055098,
#  'autocorrelation_72_lag': -0.23423609800987302,
#  'autocorrelation_73_lag': -0.23817406508057903,
#  'autocorrelation_74_lag': -0.2395905551543893,
#  'autocorrelation_75_lag': -0.23845645517925865,
#  'autocorrelation_76_lag': -0.23480331114590977,
#  'autocorrelation_77_lag': -0.22865376957421008,
#  'autocorrelation_78_lag': -0.22011366981774258,
#  'autocorrelation_79_lag': -0.20924783552593157,
#  'autocorrelation_80_lag': -0.19622041017669212,
#  'autocorrelation_81_lag': -0.18116571798339698,
#  'autocorrelation_82_lag': -0.1642951706641043,
#  'autocorrelation_83_lag': -0.1458145827968449,
#  'autocorrelation_84_lag': -0.1259632291083326,
#  'autocorrelation_85_lag': -0.10500601312624282,
#  'autocorrelation_86_lag': -0.08319860396399147,
#  'autocorrelation_87_lag': -0.06083801272293344,
#  'autocorrelation_88_lag': -0.038245150247034274,
#  'autocorrelation_89_lag': -0.015753055172882474,
#  'autocorrelation_90_lag': 0.0062992297851783095,
#  'autocorrelation_91_lag': 0.0275549013882774,
#  'autocorrelation_92_lag': 0.047690587967286445,
#  'autocorrelation_93_lag': 0.06636662193133662,
#  'autocorrelation_94_lag': 0.08331673021314653,
#  'autocorrelation_95_lag': 0.09826578021067985,
#  'autocorrelation_96_lag': 0.11099911365235117,
#  'autocorrelation_97_lag': 0.12131740133164379,
#  'autocorrelation_98_lag': 0.1290756745138512,
#  'autocorrelation_99_lag': 0.13419280007897463,
#  'autocorrelation_100_lag': 0.13666303526893825,
#  'autocorrelation_101_lag': 0.13657729074790667,
#  'autocorrelation_102_lag': 0.13406201739160936,
#  'autocorrelation_103_lag': 0.12936174032812559,
#  'autocorrelation_104_lag': 0.12270916916858289,
#  'autocorrelation_105_lag': 0.11444500934072939,
#  'autocorrelation_106_lag': 0.10486749702664581,
#  'autocorrelation_107_lag': 0.09433152677701631,
#  'autocorrelation_108_lag': 0.08313246202596061,
#  'autocorrelation_109_lag': 0.0715963018310512,
#  'autocorrelation_110_lag': 0.05998600287668383,
#  'autocorrelation_111_lag': 0.04859828514513376,
#  'autocorrelation_112_lag': 0.037685648957003985,
#  'autocorrelation_113_lag': 0.027478085957334603,
#  'autocorrelation_114_lag': 0.0181681722671473,
#  'autocorrelation_115_lag': 0.009909665968623095,
#  'autocorrelation_116_lag': 0.002821741733643519,
#  'autocorrelation_117_lag': -0.00300466400314553,
#  'autocorrelation_118_lag': -0.007503997347817638,
#  'autocorrelation_119_lag': -0.010625015895813123,
#  'autocorrelation_120_lag': -0.012325415669013526,
#  'autocorrelation_121_lag': -0.0125856804336185,
#  'autocorrelation_122_lag': -0.011353917397044102,
#  'autocorrelation_123_lag': -0.008640340111281892,
#  'autocorrelation_124_lag': -0.004444002195379161,
#  'autocorrelation_125_lag': 0.0011459716970619847,
#  'autocorrelation_126_lag': 0.008024276491448434,
#  'autocorrelation_127_lag': 0.016007413537130217,
#  'autocorrelation_128_lag': 0.024900679680806382,
#  'autocorrelation_129_lag': 0.034467441568183335,
#  'autocorrelation_130_lag': 0.04449255071153026,
#  'autocorrelation_131_lag': 0.054724981584468375,
#  'autocorrelation_132_lag': 0.0649283529513128,
#  'autocorrelation_133_lag': 0.07486023583017931,
#  'autocorrelation_134_lag': 0.08425334108052743,
#  'autocorrelation_135_lag': 0.09286967368238697,
#  'autocorrelation_136_lag': 0.10044944218344988,
#  'autocorrelation_137_lag': 0.10680583073314104,
#  'autocorrelation_138_lag': 0.11177482017317837,
#  'autocorrelation_139_lag': 0.11528137627123722,
#  'autocorrelation_140_lag': 0.11728901333065139,
#  'autocorrelation_141_lag': 0.11784216552115563,
#  'autocorrelation_142_lag': 0.11700421950255165,
#  'autocorrelation_143_lag': 0.11491118835484476,
#  'autocorrelation_144_lag': 0.11171929631272941,
#  'autocorrelation_145_lag': 0.10761602163184755,
#  'autocorrelation_146_lag': 0.10282301454858421,
#  'autocorrelation_147_lag': 0.09753566441596048,
#  'autocorrelation_148_lag': 0.09199804218514013,
#  'autocorrelation_149_lag': 0.08632531973089491,
#  'autocorrelation_150_lag': 0.08062661974764908,
#  'autocorrelation_151_lag': 0.07486421274036374,
#  'autocorrelation_152_lag': 0.06896410795034975,
#  'autocorrelation_153_lag': 0.06277549981455176,
#  'autocorrelation_154_lag': 0.05615398478058582,
#  'autocorrelation_155_lag': 0.04899978820991405,
#  'autocorrelation_156_lag': 0.04129976167645101,
#  'autocorrelation_157_lag': 0.03311816889647373,
#  'autocorrelation_158_lag': 0.024602284789287502,
#  'autocorrelation_159_lag': 0.01591817680578868,
#  'autocorrelation_160_lag': 0.00725008312055939,
#  'autocorrelation_161_lag': -0.0012557564756580767,
#  'autocorrelation_162_lag': -0.00947083792956666,
#  'autocorrelation_163_lag': -0.017312281389553714,
#  'autocorrelation_164_lag': -0.0247189855851584,
#  'autocorrelation_165_lag': -0.031639809528540605,
#  'autocorrelation_166_lag': -0.03803914540951081,
#  'autocorrelation_167_lag': -0.04387226238877253,
#  'autocorrelation_168_lag': -0.049152615689111265,
#  'autocorrelation_169_lag': -0.05385570254721142,
#  'autocorrelation_170_lag': -0.05799864269540033,
#  'autocorrelation_171_lag': -0.06154046109145072,
#  'autocorrelation_172_lag': -0.06444174399646961,
#  'autocorrelation_173_lag': -0.06664744044733491,
#  'autocorrelation_174_lag': -0.06814523313389212,
#  'autocorrelation_175_lag': -0.06894024196156347,
#  'autocorrelation_176_lag': -0.06906363720103496,
#  'autocorrelation_177_lag': -0.06852643160497245,
#  'autocorrelation_178_lag': -0.0673848871524738,
#  'autocorrelation_179_lag': -0.06568176286236403,
#  'autocorrelation_180_lag': -0.06348874622492767,
#  'autocorrelation_181_lag': -0.060848836378872076,
#  'autocorrelation_182_lag': -0.05781117175975187,
#  'autocorrelation_183_lag': -0.05440202631090682,
#  'autocorrelation_184_lag': -0.050665634337426636,
#  'autocorrelation_185_lag': -0.04664854971179222,
#  'autocorrelation_186_lag': -0.04242046529204621,
#  'autocorrelation_187_lag': -0.03805627213778047,
#  'autocorrelation_188_lag': -0.03361495543079271,
#  'autocorrelation_189_lag': -0.029206409654693396,
#  'autocorrelation_190_lag': -0.02490074557943495,
#  'autocorrelation_191_lag': -0.020824782404927918,
#  'autocorrelation_192_lag': -0.017019819373232558,
#  'autocorrelation_193_lag': -0.013567979935248997,
#  'autocorrelation_194_lag': -0.010461701681867209,
#  'autocorrelation_195_lag': -0.007693335957093082,
#  'autocorrelation_196_lag': -0.005201396760946964,
#  'autocorrelation_197_lag': -0.0029153563860458832,
#  'autocorrelation_198_lag': -0.0007719285171457811,
#  'autocorrelation_199_lag': 0.001282605090884241,
#  'autocorrelation_200_lag': 0.003266911420446216,
#  'lag_max_autocorrelation_Hz': 20.0,
#  'max_autocorrelation': 0.13666303526893825}

# %% [markdown]
# Compute all features over the data set.

# %%
all_features = pd.DataFrame(
    [get_features(signal.data.flatten()) for signal in data.X_train]
)

# %%
all_features
# Out:
#          mean       std       min       max      skew   quarter  two_quarter  \
# 0   -0.000044  0.053476 -0.325073  0.291504  0.286963 -0.027130    -0.000610
# 1   -0.000026  0.021232 -0.109467  0.139496  0.389185 -0.011505    -0.000244
# 2   -0.000069  0.034245 -0.253387  0.291596  1.362185 -0.007721    -0.000031
# 3   -0.000026  0.075533 -0.440369  0.644653  1.424710 -0.020012    -0.000275
# 4   -0.000021  0.126608 -1.000000  0.999969  0.238795 -0.017639     0.000275
# ..        ...       ...       ...       ...       ...       ...          ...
# 199 -0.000015  0.032546 -0.242615  0.205414 -0.104041 -0.009369    -0.000214
# 200  0.000016  0.043400 -0.271423  0.268433  0.385208 -0.017853    -0.001068
# 201 -0.000140  0.022984 -0.150848  0.155762 -0.153763 -0.009125     0.000549
# 202 -0.000051  0.079495 -0.745911  0.765869  0.662124 -0.016571    -0.000122
# 203 -0.000006  0.035637 -0.319519  0.148407 -1.415224 -0.015160     0.001236
#
#      three_quarter  fourier_0.0-20.0_Hz  fourier_20.0-40.0_Hz  ...  \
# 0         0.025116            17.425511             18.089893  ...
# 1         0.010864            17.947738             17.998736  ...
# 2         0.007477            15.761979             17.992996  ...
# 3         0.018646            15.773631             18.058406  ...
# 4         0.016685            15.738893             18.259682  ...
# ..             ...                  ...                   ...  ...
# 199       0.009186            16.177246             18.484476  ...
# 200       0.015930            17.137829             18.184900  ...
# 201       0.009155            17.238087             18.407336  ...
# 202       0.014435            16.915178             18.260303  ...
# 203       0.016998            17.264797             18.159425  ...
#
#      autocorrelation_193_lag  autocorrelation_194_lag  \
# 0                  -0.013568                -0.010462
# 1                   0.147982                 0.143621
# 2                   0.007707                 0.006197
# 3                   0.003933                 0.008041
# 4                   0.025114                 0.024158
# ..                       ...                      ...
# 199                 0.028165                 0.031262
# 200                -0.022602                -0.024940
# 201                 0.072303                 0.069616
# 202                 0.002492                 0.002306
# 203                -0.050263                -0.051416
#
#      autocorrelation_195_lag  autocorrelation_196_lag  \
# 0                  -0.007693                -0.005201
# 1                   0.139093                 0.134445
# 2                   0.004491                 0.002655
# 3                   0.011920                 0.015518
# 4                   0.023134                 0.022036
# ..                       ...                      ...
# 199                 0.033769                 0.035721
# 200                -0.026746                -0.028053
# 201                 0.066457                 0.062866
# 202                 0.002059                 0.001747
# 203                -0.052067                -0.052164
#
#      autocorrelation_197_lag  autocorrelation_198_lag  \
# 0                  -0.002915                -0.000772
# 1                   0.129681                 0.124822
# 2                   0.000759                -0.001193
# 3                   0.018804                 0.021765
# 4                   0.020845                 0.019556
# ..                       ...                      ...
# 199                 0.037127                 0.038019
# 200                -0.028886                -0.029261
# 201                 0.058874                 0.054534
# 202                 0.001358                 0.000929
# 203                -0.051695                -0.050671
#
#      autocorrelation_199_lag  autocorrelation_200_lag  \
# 0                   0.001283                 0.003267
# 1                   0.119951                 0.115106
# 2                  -0.003117                -0.005015
# 3                   0.024399                 0.026711
# 4                   0.018152                 0.016617
# ..                       ...                      ...
# 199                 0.038402                 0.038395
# 200                -0.029207                -0.028744
# 201                 0.049894                 0.045040
# 202                 0.000435                -0.000088
# 203                -0.049099                -0.047036
#
#      lag_max_autocorrelation_Hz  max_autocorrelation
# 0                     20.000000             0.136663
# 1                     10.869565             0.169397
# 2                     40.816327             0.113092
# 3                     30.769231             0.159935
# 4                     37.037037             0.283012
# ..                          ...                  ...
# 199                   28.571429             0.372528
# 200                   23.809524             0.155785
# 201                   18.867925             0.087918
# 202                   25.000000             0.079607
# 203                   18.348624             0.081170
#
# [204 rows x 261 columns]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %% [markdown]
# * Answer : At the end, we have 261 features

# %% [markdown]
# # Feature selection

# %% [markdown]
# ## Unsupervised selection

# %% [markdown]
# ### Sanity checks

# %% [markdown]
# #### Low variance threshold

# %%
fig, ax = fig_ax(figsize=(20, 5))
all_features.std().sort_values().plot(ax=ax)

# change the height of the horizontal line here
ax.axhline(0.01, ls="--", color="k")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Choose a variance threshold (name it <tt>variance_threshold</tt>).</p>
# </div>

# %%
variance_threshold = 1e-2

# %% [markdown]
# Be careful when dropping low variance features, they might still be informative. Quickly check that it makes sense to drop them.

# %%
low_variance_features = all_features.std() < variance_threshold
low_variance_features = low_variance_features[
    low_variance_features
].index.to_numpy()
print(f"There are {len(low_variance_features)} features to drop.")
print(low_variance_features)
# Out:
# There are 3 features to drop.
# ['mean' 'two_quarter' 'autocorrelation_0_lag']

# %% [markdown]
# The following cell drops the low-variance features. Only execute it when you are sure of the features you want to remove.

# %%
all_features.drop(columns=low_variance_features, inplace=True, errors="ignore")
print(f"There are {all_features.shape[1]} features left.")
# Out:
# There are 258 features left.

# %% [markdown]
# #### Check outliers

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> One feature has larger variations than the others: which one is it? (Name it <tt>feature_to_check</tt>.) Show the associated boxplot.</p>
# </div>

# %%
feature_to_check = "lag_max_autocorrelation_Hz"

# %%
all_features[feature_to_check].plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Check the outliers. Is there something we can do to remediate this issue?</p>
# </div>

# %% [markdown]
# * Answer : Il y a un outlier avec un lag_max à 1000Hz, il y a un point tous les 2 échantillons, c'est clairement du bruit.
#     Interprétons ce résultat : Dans la fonction d'autocorrélation, le maximum local est calculé selon s'il est plus grand que son unique voisin de gauche et de droite. Pour rendre plus robuste cette fonction, on peut étendre cela à plusieurs voisins de gauche et de droite. Donc on va changer l'ordre de voisinage sur lequel on vérifie la supériorité, au lieu d'un point on va prendre 20 points de part et d'autre. Dans le code, cela correspond à order = 20

# %% [markdown]
# ### Multicollinearity
#
# Multicollinearity degrades numerical stability and interpretability.
# Compute the rank-based Spearman correlation.
# Features with a correlation above a threshold are grouped together in a cluster.
# We then choose a single feature from each cluster.

# %% [markdown]
# 2 blocs : - statistic features
# - Fourier features

# %%
correlation_threshold = 0.8

# %%
corr = pdist(
    all_features.to_numpy().T, metric="correlation"
)  # distance matrix
plt.imshow(squareform(corr))

# %%
fig, ax = fig_ax((20, 10))
corr_linkage = hierarchy.average(corr)
dendro = hierarchy.dendrogram(
    corr_linkage, ax=ax, color_threshold=1 - correlation_threshold
)

# %%
# compute the clusters
cluster_ids = hierarchy.fcluster(
    corr_linkage, 1 - correlation_threshold, criterion="distance"
)

# print the largest clusters
largest_cluster_ind = np.bincount(cluster_ids).argmax()
print(
    f"The largest cluster is {all_features.columns[cluster_ids==largest_cluster_ind].tolist()}."
)

# for each cluster, only keep the first feature
keep_features = list()
for cluster in np.unique(cluster_ids):
    cluster_indexes = np.where(cluster_ids == cluster)[0]
    keep_features.append(all_features.columns[cluster_indexes[0]])
# Out:
# The largest cluster is ['fourier_360.0-380.0_Hz', 'fourier_380.0-400.0_Hz', 'fourier_400.0-420.0_Hz', 'fourier_420.0-440.0_Hz', 'fourier_440.0-460.0_Hz', 'fourier_460.0-480.0_Hz', 'fourier_480.0-500.0_Hz', 'fourier_500.0-520.0_Hz', 'fourier_520.0-540.0_Hz', 'fourier_540.0-560.0_Hz', 'fourier_560.0-580.0_Hz', 'fourier_580.0-600.0_Hz', 'fourier_600.0-620.0_Hz', 'fourier_620.0-640.0_Hz', 'fourier_640.0-660.0_Hz', 'fourier_660.0-680.0_Hz', 'fourier_680.0-700.0_Hz', 'fourier_700.0-720.0_Hz', 'fourier_720.0-740.0_Hz'].

# %%
# Reduce the number of features
all_features = all_features[keep_features]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %%
print(len(keep_features))
# Out:
# 38

# %% [markdown]
# * Ce sont bien tous les coef sauf ceux dont on ne voulait plus car il correspond aux coefs de Fourier avec des fréquences > 200Hz

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components=2, whiten=True).fit(all_features)

# %%
# select the 5 most important features (with highest norm).
top_features_for_pca = np.linalg.norm(pca.components_, axis=0).argsort()[-5:]

for feature_ind in top_features_for_pca:
    msg = f"{all_features.columns[feature_ind]}: {(pca.components_.T[feature_ind]**2).sum():.3f}"
    print(msg)
# Out:
# fourier_160.0-180.0_Hz: 0.087
# fourier_240.0-260.0_Hz: 0.165
# fourier_360.0-380.0_Hz: 0.251
# fourier_740.0-760.0_Hz: 0.419
# lag_max_autocorrelation_Hz: 0.998

# %%
# plot the 2D projection of the top 5 features
fig, ax = fig_ax(figsize=(8, 8))
ax.axis("equal")
for feature_ind in top_features_for_pca:
    dx, dy = pca.components_.T[feature_ind]
    ax.plot([0, dx], [0, dy], label=all_features.columns[feature_ind])
ax.set_xlabel(f"PC1 ({pca.explained_variance_[0]:.1f}% of variance)")
ax.set_ylabel(f"PC1 ({pca.explained_variance_[1]:.1f}% of variance)")
_ = plt.legend()

# %% [markdown]
# ## Supervised selection

# %% [markdown]
# Three main classes of methods:
#
# - **Filter methods.** We test the adequacy of the feature with the annotations, thanks to several criterion/scores (e.g. correlation).
# - **Wrapper methods.** We test the features on a supervised classification task, by trying several combinations. The best features are kept.
# - **Embedded methods.** Mixed approaches where we jointly infer the relevance of the features and classify the data (decision tree, sparse methods...)

# %% [markdown]
# ### Filter methods
#
# If a feature is highly correlated with a label, it can help achieve good classification performance.
#
# For classification tasks, ANOVA.

# %%
labels = data.y_train
statistics, pvalues = f_oneway(
    all_features[labels == "Abnormal"], all_features[labels == "Normal"]
)

# %%
for ind in statistics.argsort()[::-1]:
    print(f"{all_features.columns[ind]}: {statistics[ind]:.3f}")
# Out:
# max: 16.456
# fourier_740.0-760.0_Hz: 14.957
# min: 13.055
# fourier_40.0-60.0_Hz: 12.309
# autocorrelation_49_lag: 11.991
# autocorrelation_14_lag: 11.314
# autocorrelation_22_lag: 7.894
# fourier_0.0-20.0_Hz: 6.644
# autocorrelation_136_lag: 4.152
# std: 2.934
# autocorrelation_57_lag: 2.772
# fourier_360.0-380.0_Hz: 2.462
# fourier_60.0-80.0_Hz: 2.115
# fourier_20.0-40.0_Hz: 1.938
# autocorrelation_148_lag: 1.884
# fourier_240.0-260.0_Hz: 1.821
# fourier_80.0-100.0_Hz: 1.728
# skew: 1.505
# autocorrelation_124_lag: 1.199
# lag_max_autocorrelation_Hz: 1.130
# fourier_120.0-140.0_Hz: 1.053
# autocorrelation_104_lag: 0.789
# autocorrelation_1_lag: 0.701
# autocorrelation_71_lag: 0.434
# autocorrelation_81_lag: 0.430
# autocorrelation_95_lag: 0.396
# autocorrelation_191_lag: 0.361
# autocorrelation_3_lag: 0.266
# max_autocorrelation: 0.213
# autocorrelation_62_lag: 0.169
# autocorrelation_177_lag: 0.102
# autocorrelation_30_lag: 0.045
# fourier_160.0-180.0_Hz: 0.041
# autocorrelation_169_lag: 0.039
# autocorrelation_157_lag: 0.014
# autocorrelation_116_lag: 0.011
# quarter: 0.005
# autocorrelation_89_lag: 0.000

# %% [markdown]
# ### Wrapper methods
#
# For a given learning algorithm, wrapper methods repeatedly select a subset of features and evaluate the selected features. Several procedures exist to select a subset but the most common are greedy and iterative; they either remove (backward selection) or add a feature (forward selection) sequentially.

# %%
# At each steps, SequentialFeatureSelector adds the best scoring feature to
# the set of selected features.
# For a given estimator, the score is computed with cross-validation.
knn = KNeighborsClassifier(n_neighbors=3)
sfs = SequentialFeatureSelector(
    knn, n_features_to_select=20, cv=5, scoring=make_scorer(accuracy_score)
)
sfs.fit(all_features, labels)

print("Selected features:")
print(all_features.columns[sfs.get_support()].tolist())
# Out:
# Selected features:
# ['quarter', 'autocorrelation_1_lag', 'autocorrelation_3_lag', 'autocorrelation_116_lag', 'autocorrelation_124_lag', 'autocorrelation_148_lag', 'autocorrelation_136_lag', 'autocorrelation_169_lag', 'autocorrelation_157_lag', 'autocorrelation_191_lag', 'autocorrelation_177_lag', 'fourier_360.0-380.0_Hz', 'fourier_740.0-760.0_Hz', 'autocorrelation_95_lag', 'autocorrelation_104_lag', 'autocorrelation_30_lag', 'fourier_60.0-80.0_Hz', 'max_autocorrelation', 'std', 'autocorrelation_81_lag']

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Run the same selection as above, but with backward selection (<tt>sklearn.feature_selection.RFE</tt>).</p>
# </div>

# %%
sfs = SequentialFeatureSelector(
    knn, n_features_to_select=20, direction = 'backward', 
    cv=5, scoring=make_scorer(accuracy_score)
)
sfs.fit(all_features, labels)

print("Selected features:")
print(all_features.columns[sfs.get_support()].tolist())
# Out:
# Selected features:
# ['autocorrelation_14_lag', 'fourier_20.0-40.0_Hz', 'autocorrelation_177_lag', 'autocorrelation_22_lag', 'fourier_80.0-100.0_Hz', 'fourier_240.0-260.0_Hz', 'fourier_160.0-180.0_Hz', 'fourier_360.0-380.0_Hz', 'fourier_740.0-760.0_Hz', 'autocorrelation_104_lag', 'autocorrelation_30_lag', 'fourier_60.0-80.0_Hz', 'skew', 'autocorrelation_49_lag', 'autocorrelation_57_lag', 'autocorrelation_62_lag', 'max_autocorrelation', 'autocorrelation_71_lag', 'autocorrelation_89_lag', 'autocorrelation_81_lag']

# %% [markdown]
# ### Embedded methods
#
# Such methods use the intrinsic structure of a learning algorithm to embed feature selection into the underlying model.

# %%
rf = RandomForestClassifier().fit(all_features, labels)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Print features in descending order of importance, measured by the random forest feature importance (see the <tt>feature_importances_</tt> attribute).</p>
# </div>

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)
print(indices)
# Out:
# [37  6  7  2 14 11  8  5  4 36 17 13 22 15  9 12 19 30 23 25 18 20 35 32
#  16 28 10 29  3 31 27 26  1  0 24 34 33 21]

# %%
np.sort(importances)
# Out:
# array([0.01498259, 0.01515901, 0.01615933, 0.016855  , 0.01784663,
#        0.01812115, 0.01951159, 0.01966443, 0.01968857, 0.0202063 ,
#        0.02024658, 0.02049844, 0.02096778, 0.02112387, 0.02115201,
#        0.02126575, 0.02146569, 0.02180323, 0.02210103, 0.02229907,
#        0.02238154, 0.02265036, 0.02408049, 0.02511991, 0.02578068,
#        0.02649968, 0.02666573, 0.02708467, 0.02787112, 0.02878975,
#        0.03125768, 0.03202835, 0.03404993, 0.03445932, 0.03580566,
#        0.04132991, 0.05693798, 0.08608918])

# %%
all_features.columns[indices]
# Out:
# Index(['autocorrelation_81_lag', 'fourier_20.0-40.0_Hz',
#        'autocorrelation_116_lag', 'autocorrelation_1_lag',
#        'autocorrelation_177_lag', 'autocorrelation_169_lag',
#        'autocorrelation_124_lag', 'autocorrelation_3_lag',
#        'fourier_0.0-20.0_Hz', 'autocorrelation_89_lag',
#        'fourier_80.0-100.0_Hz', 'autocorrelation_191_lag',
#        'autocorrelation_95_lag', 'autocorrelation_22_lag',
#        'autocorrelation_148_lag', 'autocorrelation_157_lag',
#        'fourier_160.0-180.0_Hz', 'autocorrelation_62_lag',
#        'autocorrelation_104_lag', 'autocorrelation_30_lag',
#        'fourier_240.0-260.0_Hz', 'fourier_360.0-380.0_Hz',
#        'autocorrelation_71_lag', 'max_autocorrelation',
#        'fourier_120.0-140.0_Hz', 'autocorrelation_49_lag',
#        'autocorrelation_136_lag', 'autocorrelation_57_lag',
#        'autocorrelation_14_lag', 'lag_max_autocorrelation_Hz', 'skew',
#        'fourier_60.0-80.0_Hz', 'quarter', 'min', 'fourier_40.0-60.0_Hz', 'max',
#        'std', 'fourier_740.0-760.0_Hz'],
#       dtype='object')
